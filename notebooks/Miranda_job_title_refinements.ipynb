# %%
import numpy as np
import pandas as pd
import re
from collections import Counter

# %%
data= pd.read_excel('/Users/dongxujia/Dropbox/DS-Discovery_GenderDiversity/04_Data/raw/jobads.xlsx')

# %%
data.shape
# Out:
# (6472, 5)

# %%
data.id.nunique()
# Out:
# 6472

# %%
data.head()
# Out:
#      id                                    job_title_en  \
# 0  5606                    flash and deliver prototypes
# 1    14       physical verification engineer lnd_150019
# 2  5371  3d printing specialist for packaging materials
# 3   831               a strengthening support employee
# 4   360                                account manager
#
#                                   job_requirement_en  \
# 0                                                NaN
# 1  your duties as a system test  verification eng...
# 2  academic degree in mechanical engineering  pac...
# 3  successfully completed natural or engineering ...
# 4  a degree in the engineering field several year...
#
#                                   job_description_en  \
# 0  job description\n\nconstruction and electrical...
# 1  Your duties as a system test & verification en...
# 2  Establishing a global 3d printing strategy for...
# 3  we are looking for an active and motivated sup...
# 4  as accoutn manager (m / w) of the business uni...
#
#                                         job_category
# 0                           engineering--engineering
# 1  research and development--mechanical,engineeri...
# 2                                   logistics--other
# 3  research and development--other,research and d...
# 4  marketing and sales--service customer support,...

# %% [markdown]
# ### • 1) Classify job titles using a two-factor model
# 	○ Find the area of the job (e.g. software engineering)
# 		○ (for the area the first element of the job category might be helpful) and
# 	○ and the rank of the job (e.g. lead, senior, group lead, team leader, assistant) if applicable.
#
#
# ### • 2) Classify job titles using the degree requirements
# 	○ Isolate the type of degree and the number of years of worker experience for each position
# 	○ Group positions by degree x experience groups

# %%
data.head()
# Out:
#      id                                    job_title_en  \
# 0  5606                    flash and deliver prototypes
# 1    14       physical verification engineer lnd_150019
# 2  5371  3d printing specialist for packaging materials
# 3   831               a strengthening support employee
# 4   360                                account manager
#
#                                   job_requirement_en  \
# 0                                                NaN
# 1  your duties as a system test  verification eng...
# 2  academic degree in mechanical engineering  pac...
# 3  successfully completed natural or engineering ...
# 4  a degree in the engineering field several year...
#
#                                   job_description_en  \
# 0  job description\n\nconstruction and electrical...
# 1  Your duties as a system test & verification en...
# 2  Establishing a global 3d printing strategy for...
# 3  we are looking for an active and motivated sup...
# 4  as accoutn manager (m / w) of the business uni...
#
#                                         job_category
# 0                           engineering--engineering
# 1  research and development--mechanical,engineeri...
# 2                                   logistics--other
# 3  research and development--other,research and d...
# 4  marketing and sales--service customer support,...

# %% [markdown]
# ### Use job_category to extract job_area

# %%
# some entries in job_category are null types
data.job_category.isnull().value_counts()
# Out:
# False    6440
# True       32
# Name: job_category, dtype: int64

# %%
# change these to None
data.loc[data.job_category.isnull(),['job_category']] = None

# %%
data.job_category.str.contains("--", na=False).value_counts()
# Out:
# True     6415
# False      57
# Name: job_category, dtype: int64

# %%
# note that job_categories that are without "--" are either None or "general management"

data[~data.job_category.str.contains("--", na=False)].head()
# Out:
#        id                                       job_title_en  \
# 40   4611                                    acquisition tpl
# 392  2062                   bu head of engine systems  iran
# 477  6423     category buyer for embedded software licenses
# 562  2405  cbs reporting controller admin coach  parttime...
# 820  6419  control  software engineer replacement panagio...
#
#                                     job_requirement_en  \
# 40                                             missing
# 392  academic degree in electrical engineering mech...
# 477                                            missing
# 562  successful completion of degree in business ad...
# 820                                            missing
#
#                                     job_description_en        job_category
# 40   ? guided by supply phases to tire pressure con...                None
# 392  target is to build up and develop a joint vent...  general management
# 477  description:\n license price and contract nego...                None
# 562  develop worldwide cbs reporting strategy for c...  general management
# 820  Perform software projects for technical concep...                None

# %%
# Create a new column called "job_area" that keeps the word before "--" in job_category.
# For entries in job_category that do not contain "--" (either None or "general management"),
# fill in None for the former and "management" for the latter.

# %%
data.loc[data.job_category.str.contains(
    "--", na=False),'job_area'] = data.job_category.str.split("--").str[0]

# %%
data.loc[data.job_category.isnull(),'job_area'] = None

# %%
data.loc[data.job_category == "general management",'job_area'] = "management"

# %%
data.job_area = data.job_area.str.replace(","," ")

# %%
# create another column job_area_oneword that combine each entry in job_area as one word using underscores

# %%
data['job_area_oneword'] = data.job_area.str.replace(" ","_")

# %%
data.head()
# Out:
#      id                                    job_title_en  \
# 0  5606                    flash and deliver prototypes
# 1    14       physical verification engineer lnd_150019
# 2  5371  3d printing specialist for packaging materials
# 3   831               a strengthening support employee
# 4   360                                account manager
#
#                                   job_requirement_en  \
# 0                                                NaN
# 1  your duties as a system test  verification eng...
# 2  academic degree in mechanical engineering  pac...
# 3  successfully completed natural or engineering ...
# 4  a degree in the engineering field several year...
#
#                                   job_description_en  \
# 0  job description\n\nconstruction and electrical...
# 1  Your duties as a system test & verification en...
# 2  Establishing a global 3d printing strategy for...
# 3  we are looking for an active and motivated sup...
# 4  as accoutn manager (m / w) of the business uni...
#
#                                         job_category  \
# 0                           engineering--engineering
# 1  research and development--mechanical,engineeri...
# 2                                   logistics--other
# 3  research and development--other,research and d...
# 4  marketing and sales--service customer support,...
#
#                    job_area          job_area_oneword
# 0               engineering               engineering
# 1  research and development  research_and_development
# 2                 logistics                 logistics
# 3  research and development  research_and_development
# 4       marketing and sales       marketing_and_sales

# %%
#Some entries in job_area_oneword still have multiple listings (general management + other stuff) 
# replace the ones that starts with general management with general management.

# %%
data.loc[data.job_area_oneword.str.startswith(
    'general_management',na=False),'job_area_oneword'] = 'general_management'

# %%
job_area_oneword_counter = Counter(data.job_area_oneword.astype(str))

# %%
# 20 most common job_area_oneword

job_area_oneword_counter.most_common(20)
# Out:
# [('engineering', 1865),
#  ('research_and_development', 931),
#  ('quality', 443),
#  ('marketing_and_sales', 439),
#  ('finance_and_controlling', 373),
#  ('information_technology', 373),
#  ('project_management', 317),
#  ('human_resources', 291),
#  ('logistics', 261),
#  ('purchasing', 256),
#  ('manufacturing_operations_and_production', 208),
#  ('industrial_engineering', 183),
#  ('administration_and_assistance', 158),
#  ('general_management', 68),
#  ('key_account_management', 67),
#  ('communications', 62),
#  ('None', 32),
#  ('law_patents_and_licences', 27),
#  ('facility_management', 26),
#  ('management', 25)]

# %%
# create a column called "job_area_broader" to create broader job area indicator using the classification below:

# engineering = engineering, industrial_engineering, research_and_development
# finance = finance_and_controlling, law_patents_and_licences, auditing
# marketing_and_sales = marketing_and_sales, key_account_management, communications
# health_safety_and_security_environment = health_safety_and_security, environment

# %%
data['job_area_broader'] = data.job_area_oneword

# %%
data.loc[(data.job_area_oneword == 'industrial_engineering')|(
    data.job_area_oneword == 'research_and_development'), 'job_area_broader'] = 'engineering'

# %%
data.loc[(data.job_area_oneword == 'finance_and_controlling')|(
    data.job_area_oneword == 'law_patents_and_licences')|(
    data.job_area_oneword == 'auditing'), 'job_area_broader'] = 'finance'

# %%
data.loc[(data.job_area_oneword == 'key_account_management')|(
    data.job_area_oneword == 'communications'), 'job_area_broader'] = 'marketing_and_sales'

# %%
data.loc[(data.job_area_oneword == 'health_safety_and_security')|(
    data.job_area_oneword == 'environment'), 'job_area_broader'] = 'health_safety_and_security_environment'

# %%
# There are 32 entries of job_category that are none
# impute a job_area_broader for these entries by looking at the job title and description 
# and find the closest match

# %%
l = '6419 51 29 41 3301 5738 3799 3825 6443 3394 783 4006 4007 4248 4250 4251 4454 4452 3380 4000 5295 4350 4402'

# %%
engineering_index = l.split(' ')

# %%
engineering_index = [int(i) for i in engineering_index]

# %%
for i in engineering_index:
    data.loc[data.id == i,'job_area_broader'] = 'engineering'

# %%
data.loc[data.id == 4611,'job_area_broader'] = 'facility_management'
data.loc[data.id == 6423,'job_area_broader'] = 'purchasing'
data.loc[data.id == 3824,'job_area_broader'] = 'marketing_and_sales'
data.loc[data.id == 3425,'job_area_broader'] = 'logistics'
data.loc[data.id == 4411,'job_area_broader'] = 'management'
data.loc[data.id == 3480,'job_area_broader'] = 'finance'
data.loc[data.id == 2556,'job_area_broader'] = 'human_resources'
data.loc[data.id == 3614,'job_area_broader'] = 'administration_and_assistance'
data.loc[data.id == 702,'job_area_broader'] = 'project_management'

# %%
data.job_area_broader.isnull().value_counts()
# Out:
# False    6472
# Name: job_area_broader, dtype: int64

# %%
job_area_broader_counter = Counter(data.job_area_broader.astype(str))

# %%
# job_area_broader in descending order of popularity

job_area_broader_counter.most_common()
# Out:
# [('engineering', 3002),
#  ('marketing_and_sales', 569),
#  ('quality', 443),
#  ('finance', 420),
#  ('information_technology', 373),
#  ('project_management', 318),
#  ('human_resources', 292),
#  ('logistics', 262),
#  ('purchasing', 257),
#  ('manufacturing_operations_and_production', 208),
#  ('administration_and_assistance', 159),
#  ('general_management', 68),
#  ('health_safety_and_security_environment', 38),
#  ('facility_management', 27),
#  ('management', 26),
#  ('mergers_and_acquisitions', 10)]

# %% [markdown]
# ### Extract job_rank (lead, senior, group lead, team leader, assistant)

# %%
ranks = ['manager', 'specialist', 'head', 'coach', 'assistant', 
        'expert', 'lead', 'senior', 'junior', 'director', 'supervisor']

# %%
# create column job_rank that extract ranks from job_title_en if job_title_en contain any word in the ranks list
# if no matching word from ranks list is found, then the job_rank should be None

# %%
data['job_rank'] = None

# %%
for i in ranks:
    data.loc[data.job_title_en.str.contains(i,na=False),'job_rank'] = i

# %%
data.job_rank.isnull().value_counts()
# Out:
# True     3297
# False    3175
# Name: job_rank, dtype: int64

# %%
data.head()
# Out:
#      id                                    job_title_en  \
# 0  5606                    flash and deliver prototypes
# 1    14       physical verification engineer lnd_150019
# 2  5371  3d printing specialist for packaging materials
# 3   831               a strengthening support employee
# 4   360                                account manager
#
#                                   job_requirement_en  \
# 0                                                NaN
# 1  your duties as a system test  verification eng...
# 2  academic degree in mechanical engineering  pac...
# 3  successfully completed natural or engineering ...
# 4  a degree in the engineering field several year...
#
#                                   job_description_en  \
# 0  job description\n\nconstruction and electrical...
# 1  Your duties as a system test & verification en...
# 2  Establishing a global 3d printing strategy for...
# 3  we are looking for an active and motivated sup...
# 4  as accoutn manager (m / w) of the business uni...
#
#                                         job_category  \
# 0                           engineering--engineering
# 1  research and development--mechanical,engineeri...
# 2                                   logistics--other
# 3  research and development--other,research and d...
# 4  marketing and sales--service customer support,...
#
#                    job_area          job_area_oneword     job_area_broader  \
# 0               engineering               engineering          engineering
# 1  research and development  research_and_development          engineering
# 2                 logistics                 logistics            logistics
# 3  research and development  research_and_development          engineering
# 4       marketing and sales       marketing_and_sales  marketing_and_sales
#
#      job_rank
# 0        None
# 1        None
# 2  specialist
# 3        None
# 4     manager

# %% [markdown]
# ### Extract degree and experience information from job_requirement_en

# %%
# job_requirement_en column contains null type values

# %%
data.job_requirement_en.isnull().value_counts()
# Out:
# False    6457
# True       15
# Name: job_requirement_en, dtype: int64

# %%
# job_requirement_en column contains entries that only one or two words, such as
# - "tbd", "missing", "x" , "dd", "ot", 
# "xxx","vv","xx","s","bb" "d", "cf epr", "see above"

# %%
data[data.job_requirement_en.str.split(" ").str.len() < 3].shape[0]
# Out:
# 405

# %%
# replacing these entries with None

# %%
data.loc[data.job_requirement_en.isnull(),'job_requirement_en'] = None

# %%
data.loc[data.job_requirement_en.str.split(" ").str.len() < 3,'job_requirement_en'] = None

# %%
data.job_requirement_en.isnull().value_counts()
# Out:
# False    6052
# True      420
# Name: job_requirement_en, dtype: int64

# %%
degrees = ['bachelor','bachelors','university','master','doctor','doctorate','doctoral']

# %%
# create column job_degree that extract degree requirements from job_requirement_en 
# if job_requirement_en contain any word in the degrees list
# if no matching word from degrees list is found, then the job_degree should be None

# %%
data['job_degree'] = None

# %%
for c in degrees:
    data.loc[data.job_requirement_en.str.contains(c,na=False),'job_degree'] = c

# %%
data.job_degree.isnull().value_counts()
# Out:
# True     5192
# False    1280
# Name: job_degree, dtype: int64

# %%
data.head()
# Out:
#      id                                    job_title_en  \
# 0  5606                    flash and deliver prototypes
# 1    14       physical verification engineer lnd_150019
# 2  5371  3d printing specialist for packaging materials
# 3   831               a strengthening support employee
# 4   360                                account manager
#
#                                   job_requirement_en  \
# 0                                               None
# 1  your duties as a system test  verification eng...
# 2  academic degree in mechanical engineering  pac...
# 3  successfully completed natural or engineering ...
# 4  a degree in the engineering field several year...
#
#                                   job_description_en  \
# 0  job description\n\nconstruction and electrical...
# 1  Your duties as a system test & verification en...
# 2  Establishing a global 3d printing strategy for...
# 3  we are looking for an active and motivated sup...
# 4  as accoutn manager (m / w) of the business uni...
#
#                                         job_category  \
# 0                           engineering--engineering
# 1  research and development--mechanical,engineeri...
# 2                                   logistics--other
# 3  research and development--other,research and d...
# 4  marketing and sales--service customer support,...
#
#                    job_area          job_area_oneword     job_area_broader  \
# 0               engineering               engineering          engineering
# 1  research and development  research_and_development          engineering
# 2                 logistics                 logistics            logistics
# 3  research and development  research_and_development          engineering
# 4       marketing and sales       marketing_and_sales  marketing_and_sales
#
#      job_rank job_degree
# 0        None       None
# 1        None       None
# 2  specialist       None
# 3        None       None
# 4     manager       None

# %% [markdown]
# ### Extract # years of experience information from job_requirement_en

# %%
# re.search('\w+\s\w+\s\w+\s\w+\s\w+\sexperience\s\w+\s\w+\s\w+\s\w+\s\w+\s(\w+)', str(data.iloc[2]['job_requirement_en']))

# %%
data['extracted_experience'] = None

# %%
for i in np.arange(data.shape[0]):
    regex_search = re.search('\w+\s\w+\s\w+\s\w+\s\w+\sexperience\s\w+\s\w+\s\w+\s\w+\s\w+\s(\w+)', str(
        data.loc[i]['job_requirement_en']))
    if regex_search is not None:
        data.ix[i,'extracted_experience'] = regex_search.group(0)
    else:
        data.ix[i,'extracted_experience'] = None
# Out:
# /Users/dongxujia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys
# /Users/dongxujia/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """

# %%
# 1243 entries did not find such pattern that includes "experience" information

data['extracted_experience'].isnull().value_counts()
# Out:
# False    5229
# True     1243
# Name: extracted_experience, dtype: int64

# %%
# only 135 entries contain numbers

data['extracted_experience'].str.contains('\d').value_counts()
# Out:
# False    5094
# True      135
# Name: extracted_experience, dtype: int64

# %%
data[data['extracted_experience'].str.contains('\d',na=False)]
# Out:
#         id                                       job_title_en  \
# 122   1969        algorithmic development engineer functional
# 166    231  application engineer in the area vordevelopmen...
# 181    564   area engineer it interfaces measurements systems
# 207   2386      asic  ic developer radio frequency specialist
# 315    367      assistant to president of powertrain division
# 433   4763                           business process manager
# 563   4519                                    cbs specialist
# 600   1971          cep cluster operations manager  executive
# 826    103                                        controller
# 947   1188                  customer product quality manager
# 992    316     customer technical commercial vehicle manager
# 993   5005                        customer technical manager
# 1056   145  design engineer piezo common rail diesel injec...
# 1076   725         designer in the area air spring module ess
# 1118   314  developer security sfunktionen for drive contr...
# 1204  6274  development engineer dynamic function software...
# 1219  2378  development engineer environment model  radar ...
# 1245  1030  development engineer for trousers lines in the...
# 1253  4153  development engineer function development stab...
# 1268  4969  development engineer in the area dynamic funct...
# 1338  1704  development engineer simulation for virtual fu...
# 1367  5622               development engineer solenoid valves
# 1428  4464            digital  online communications manager
# 1436   952  director launch management tr ww lean investme...
# 1476  6117                 ebusiness manager fleet check tool
# 1478  3365                ecad training and support frontend
# 1484  2198                electrical engineer automatisation
# 1660  4207                         employee quality assurance
# 1661  5755                         employee quality assurance
# 1733   574                      energy management specialist
# ...    ...                                                ...
# 4315    27          project manager technology center plastic
# 4321  3306             project purchaser  category purchaser
# 4323    83    project purchaser for technical assembly groups
# 4326   168                           project quality manager
# 4327  1936                           project quality manager
# 4351  3599                              prototype technician
# 4368    65  purchaser for capital goods and indirect mater...
# 4505    82                    quality manager machinery conti
# 4509    96                         quality manager production
# 4617  2049                                   rd quote manager
# 4618   555                                   rd quote manager
# 4670  1091  regional product manager exhaust emission and ...
# 4696  5897    requirements manager firmc engineering services
# 4837  5354                                 sap bo consultant
# 4879  1922    scm reporting specialist  limited till 12292017
# 4941   826  senior consultant within firmc business consul...
# 4942  1388  senior consultant within firmc business consul...
# 5016  4493                            senior system engineer
# 5138  1670                                software developer
# 5154  1768  software developer  functional responsible wit...
# 5243  1412  software developer w  m driver assistant funct...
# 5352  6454                       software project leader tts
# 5912  2541  systemsoftware developer for automotive comput...
# 5913  2535  systemsoftware developer for automotive comput...
# 6099  1902  teamlead logistics process improvement quality...
# 6161   209  technical project leader competence center sys...
# 6178  4947  technical project leader in the area mechanics...
# 6218  2289       technician control technology and automation
# 6369  4415                      testing and process engineer
# 6431   943  vehicle dynamics engineer for subjective tire ...
#
#                                      job_requirement_en  \
# 122   preferably embedded programming skills in c kn...
# 166   degree preferably in the fields of mechanical ...
# 181   academic degree in electrical  electronic engi...
# 207   graduation of electrical engineering  microele...
# 315   degree of engineering industrial engineering o...
# 433   conditions training as engineer optional addit...
# 563   completed studies in the technical area or sub...
# 600   bachelor degree or master degree or similar in...
# 826   completed degree in business studies or econom...
# 947   completed studies professional direction engin...
# 992   professional experience of at least 10 years i...
# 993   education university degree in engineering wit...
# 1056  mechanical engineer or something equivalent  i...
# 1076  degree in mechanical engineering or similar st...
# 1118  degree in engineering automotive engineering e...
# 1204  degree in computer science control systems veh...
# 1219  know required skills and knowledge of algorith...
# 1245  completed scientific or technical studies auto...
# 1253  degree of engineering electrical engineering a...
# 1268  a degree in electrical control engineering aut...
# 1338  iso26262 and spice processes knowledge in agil...
# 1367  degree in mechanical engineering mechatronics ...
# 1428  acadamic degree in communications media inform...
# 1436  university degree in engineering or equivalent...
# 1476  academic degree in business administration or ...
# 1478  degree in computer science or completed traini...
# 1484  academic degree in automation engineering with...
# 1660  completed commercial or technical education or...
# 1661  completed commercial or technical education or...
# 1733  degree in mechanical engineering energy or env...
# ...                                                 ...
# 4315  completed engineeringheavy study technician or...
# 4321  requirements to profile degree in engineering ...
# 4323  completed degree as economic engineer or engin...
# 4326  degree in natural science or engineering studi...
# 4327  position requirements education graduate in me...
# 4351  vocational qualifications toolmaker or measure...
# 4368  university degree in business studies economic...
# 4505  completed degree in engineering or a similar c...
# 4509  completed engineering sciences university stud...
# 4617  academical degree in engineering electrical en...
# 4618  required experience diplomingenieur vehicle sy...
# 4670  degree in industrial engineering mechatronics ...
# 4696  successfully completed university degree in el...
# 4837  academic degree in related information technol...
# 4879  degree of economics industrial engineering or ...
# 4941  university degree in vwl bwl or engineering fi...
# 4942  university degree in vwl bwl or engineering fi...
# 5016  minimum requirement bachelor of science in eng...
# 5138  degree in computer science electrical engineer...
# 5154  qualification languages english german program...
# 5243  required experience degree master degree in on...
# 5352  degree master in the field of computer science...
# 5912  degree in engineering computer science electri...
# 5913  degree in engineering computer science electri...
# 6099  university degree in the field of management b...
# 6161  completed study electrical engineering informa...
# 6178  degree in mechanical engineering or similar fi...
# 6218  completed vocational training as technician  f...
# 6369  degree in electrical engineering industrial te...
# 6431  academic degree in vehicle dynamics or compara...
#
#                                      job_description_en  \
# 122   Development of algorithms and functions accord...
# 166   meter calibration of internal combustion engin...
# 181   as to area engineer (m / f) you develop and re...
# 207   asic planification Including all Necessary doc...
# 315   active support of the executive board of the d...
# 433   Main tasks:\n\n ensures that internal processe...
# 563   as cbs specialist (m / f) for the powertrain d...
# 600   support of cep plants in eastern europe and as...
# 826   in the firmc machinery (cm) complex tire build...
# 947   series beginning customer interface for high-q...
# 992   being informed about PSRS after g30 and commun...
# 993   we are looking for a customer technical manage...
# 1056  design and change of diesel injectors beginnin...
# 1076  independent constructive elaboration of air sp...
# 1118  development safety and monitoring functions fr...
# 1204  among their tasks:\n\n development of control ...
# 1219  tasks\n\n\n\n Development of concepts for envi...
# 1245  Create development of concepts and independent...
# 1253  function development and application of normal...
# 1268  We are looking for our location in Frankfurt a...
# 1338  development of simulation and test environment...
# 1367  among their tasks:\n\n\n\n working out of conc...
# 1428  responsibility for creating and Implementing a...
# 1436  globally responsible for launch management tr ...
# 1476  this key position willdrive fleet check tool (...
# 1478  support and advice of about 2,000 users worldw...
# 1484  for our division firmc tech at our location ha...
# 1660  optimization and processing of the internal an...
# 1661  optimization and processing of the internal an...
# 1733  as energy management specialist (m / f) you ta...
# ...                                                 ...
# 4315  contact person of tcp's for producing lokation...
# 4321  Ensuring the timely procurement of everything ...
# 4323  in the firmc machinery (cm) complex tire build...
# 4326  responsible for mass care of airbag-satellite ...
# 4327  era: 95.04.07.111\n\n\n\njob description\n\n\n...
# 4351  project related warranty of the quality of all...
# 4368  manage and carry out the procurement of capita...
# 4505  in the firmc machinery (cm) complex tire build...
# 4509  execution of process and production freely gav...
# 4617  leads and tracks status of quotation projects\...
# 4618  a.mission:\n\n1. r d quote manager offered con...
# 4670  as a regional product manager (m / f) they are...
# 4696  the firmc engineering services gmbh (ces) is e...
# 4837  looking for a motivated team member to join th...
# 4879  babenhausen introduction and execution of capa...
# 4941  consultation activities and conducted by consu...
# 4942  consultation activities and conducted by consu...
# 5016  lead technical aspects of a cross functional s...
# 5138  analysis of customer / system requirements and...
# 5154  software developer / functional responsible wi...
# 5243  tasks:\n\n Development of algorithms and funct...
# 5352  coordination of all project-specific software ...
# 5912  definition of system and software requirements...
# 5913  definition of system and software requirements...
# 6099  leading the team of logistics process improvem...
# 6161  technical management of project teams\n\ncoord...
# 6178  autonomous new development of an inverter for ...
# 6218  in the R & D tires are developed complex tire ...
# 6369  Insert of test and test processes for the alig...
# 6431  making surethat all subjective characteristics...
#
#                                            job_category  \
# 122                            engineering--engineering
# 166   research and development--other,engineering--o...
# 181                                  engineering--other
# 207                  research and development--hardware
# 315              project management--project management
# 433                                      quality--other
# 563   general management,industrial engineering--ind...
# 600   quality--manufacturing and production,manufact...
# 826                finance and controlling--controlling
# 947                 quality--engineering and technology
# 992      key account management--key account management
# 993                                  engineering--other
# 1056                                 engineering--other
# 1076  engineering--engineering,research and developm...
# 1118                    research and development--other
# 1204  engineering--engineering,research and developm...
# 1219                           engineering--engineering
# 1245                   research and development--design
# 1253        engineering--engineering,engineering--other
# 1268     engineering--engineering,engineering--software
# 1338                           engineering--engineering
# 1367  engineering--engineering,engineering--other,re...
# 1428                     communications--communications
# 1436     manufacturing operations and production--other
# 1476                     marketing and sales--marketing
# 1478  information technology--installation/operation...
# 1484                           engineering--engineering
# 1660  quality--manufacturing and production,quality-...
# 1661  quality--manufacturing and production,quality-...
# 1733                           engineering--engineering
# ...                                                 ...
# 4315  engineering--engineering,manufacturing operati...
# 4321                                  purchasing--other
# 4323                    purchasing--material management
# 4326  quality--service customer support,quality--man...
# 4327                quality--engineering and technology
# 4351  manufacturing operations and production--manuf...
# 4368  purchasing--other,purchasing--distribution,pur...
# 4505              quality--manufacturing and production
# 4509  quality--other,quality--manufacturing and prod...
# 4617                           engineering--engineering
# 4618                           engineering--engineering
# 4670             project management--project management
# 4696                           engineering--engineering
# 4837  information technology--consulting,information...
# 4879                                   logistics--other
# 4941                          project management--other
# 4942                          project management--other
# 5016  project management--project management,researc...
# 5138                 research and development--software
# 5154                 research and development--software
# 5243                           engineering--engineering
# 5352                 research and development--software
# 5912  engineering--engineering,engineering--other,en...
# 5913  engineering--engineering,engineering--other,en...
# 6099                                   logistics--other
# 6161                 research and development--software
# 6178                           engineering--engineering
# 6218               research and development--mechanical
# 6369     industrial engineering--industrial engineering
# 6431                    research and development--other
#
#                                        job_area  \
# 122                                 engineering
# 166                    research and development
# 181                                 engineering
# 207                    research and development
# 315                          project management
# 433                                     quality
# 563   general management industrial engineering
# 600                                     quality
# 826                     finance and controlling
# 947                                     quality
# 992                      key account management
# 993                                 engineering
# 1056                                engineering
# 1076                                engineering
# 1118                   research and development
# 1204                                engineering
# 1219                                engineering
# 1245                   research and development
# 1253                                engineering
# 1268                                engineering
# 1338                                engineering
# 1367                                engineering
# 1428                             communications
# 1436    manufacturing operations and production
# 1476                        marketing and sales
# 1478                     information technology
# 1484                                engineering
# 1660                                    quality
# 1661                                    quality
# 1733                                engineering
# ...                                         ...
# 4315                                engineering
# 4321                                 purchasing
# 4323                                 purchasing
# 4326                                    quality
# 4327                                    quality
# 4351    manufacturing operations and production
# 4368                                 purchasing
# 4505                                    quality
# 4509                                    quality
# 4617                                engineering
# 4618                                engineering
# 4670                         project management
# 4696                                engineering
# 4837                     information technology
# 4879                                  logistics
# 4941                         project management
# 4942                         project management
# 5016                         project management
# 5138                   research and development
# 5154                   research and development
# 5243                                engineering
# 5352                   research and development
# 5912                                engineering
# 5913                                engineering
# 6099                                  logistics
# 6161                   research and development
# 6178                                engineering
# 6218                   research and development
# 6369                     industrial engineering
# 6431                   research and development
#
#                              job_area_oneword  \
# 122                               engineering
# 166                  research_and_development
# 181                               engineering
# 207                  research_and_development
# 315                        project_management
# 433                                   quality
# 563                        general_management
# 600                                   quality
# 826                   finance_and_controlling
# 947                                   quality
# 992                    key_account_management
# 993                               engineering
# 1056                              engineering
# 1076                              engineering
# 1118                 research_and_development
# 1204                              engineering
# 1219                              engineering
# 1245                 research_and_development
# 1253                              engineering
# 1268                              engineering
# 1338                              engineering
# 1367                              engineering
# 1428                           communications
# 1436  manufacturing_operations_and_production
# 1476                      marketing_and_sales
# 1478                   information_technology
# 1484                              engineering
# 1660                                  quality
# 1661                                  quality
# 1733                              engineering
# ...                                       ...
# 4315                              engineering
# 4321                               purchasing
# 4323                               purchasing
# 4326                                  quality
# 4327                                  quality
# 4351  manufacturing_operations_and_production
# 4368                               purchasing
# 4505                                  quality
# 4509                                  quality
# 4617                              engineering
# 4618                              engineering
# 4670                       project_management
# 4696                              engineering
# 4837                   information_technology
# 4879                                logistics
# 4941                       project_management
# 4942                       project_management
# 5016                       project_management
# 5138                 research_and_development
# 5154                 research_and_development
# 5243                              engineering
# 5352                 research_and_development
# 5912                              engineering
# 5913                              engineering
# 6099                                logistics
# 6161                 research_and_development
# 6178                              engineering
# 6218                 research_and_development
# 6369                   industrial_engineering
# 6431                 research_and_development
#
#                              job_area_broader    job_rank  job_degree  \
# 122                               engineering        None        None
# 166                               engineering        None        None
# 181                               engineering        None        None
# 207                               engineering  specialist        None
# 315                        project_management   assistant        None
# 433                                   quality     manager        None
# 563                        general_management  specialist        None
# 600                                   quality     manager      master
# 826                                   finance        None        None
# 947                                   quality     manager        None
# 992                       marketing_and_sales     manager        None
# 993                               engineering     manager  university
# 1056                              engineering        None        None
# 1076                              engineering        None        None
# 1118                              engineering        None        None
# 1204                              engineering        None        None
# 1219                              engineering        None        None
# 1245                              engineering        None        None
# 1253                              engineering        None        None
# 1268                              engineering        None        None
# 1338                              engineering        None        None
# 1367                              engineering        None        None
# 1428                      marketing_and_sales     manager        None
# 1436  manufacturing_operations_and_production    director  university
# 1476                      marketing_and_sales     manager        None
# 1478                   information_technology        None        None
# 1484                              engineering        None        None
# 1660                                  quality        None        None
# 1661                                  quality        None        None
# 1733                              engineering  specialist        None
# ...                                       ...         ...         ...
# 4315                              engineering     manager        None
# 4321                               purchasing        None        None
# 4323                               purchasing        None        None
# 4326                                  quality     manager        None
# 4327                                  quality     manager        None
# 4351  manufacturing_operations_and_production        None        None
# 4368                               purchasing        None  university
# 4505                                  quality     manager        None
# 4509                                  quality     manager  university
# 4617                              engineering     manager      master
# 4618                              engineering     manager        None
# 4670                       project_management     manager        None
# 4696                              engineering     manager  university
# 4837                   information_technology        None        None
# 4879                                logistics  specialist        None
# 4941                       project_management      senior  university
# 4942                       project_management      senior  university
# 5016                       project_management      senior    bachelor
# 5138                              engineering        None        None
# 5154                              engineering        None        None
# 5243                              engineering   assistant      master
# 5352                              engineering        lead      master
# 5912                              engineering        None        None
# 5913                              engineering        None        None
# 6099                                logistics        lead  university
# 6161                              engineering        lead        None
# 6178                              engineering        lead        None
# 6218                              engineering        None      master
# 6369                              engineering        None        None
# 6431                              engineering        None        None
#
#                                    extracted_experience
# 122   experience after vzyklus desirable development...
# 166   at least 2 years of experience in the automoti...
# 181   engineering and minimum 3 years experience in ...
# 207   the frequency range of 2080ghz experience with...
# 315   at least 3 years of experience in the automoti...
# 433   or project management 5 years experience in th...
# 563   solving 5s smed moderation of experience and k...
# 600   in engineering or equivalent professional expe...
# 826   more than 5 years work experience in finance a...
# 947   equivalent 23 years of professional experience...
# 992   least 10 years in engineering experience in pr...
# 993   in project management or engineering experienc...
# 1056  ideally more than 3 years experience expert kn...
# 1076  tu advantageously 2 years of experience in the...
# 1118  technology at least 3 years experience basic k...
# 1204  of iec 61508 or spiceprocesses experience with...
# 1219  environmental modeling and data fusion experie...
# 1245  at least 3 years of experience as a developmen...
# 1253  knowledge of iso26262 and spice experience in ...
# 1268  language c and embedded software experience in...
# 1338  for more than 5 years experience with leading ...
# 1367  solenoid valve hydraulics and mechatronics exp...
# 1428  several years of extensive working experience ...
# 1436  desirable at least 8 years experience in opera...
# 1476  or it management or equivalent experience at l...
# 1478  several years of sound professional experience...
# 1484  s7 with wincc first working experience with si...
# 1660  8dreport 5why spc first work experience in a s...
# 1661  8dreport 5why spc first work experience in a s...
# 1733  least 23 years of work experience good managem...
# ...                                                 ...
# 4315  etc more than 3 years experience in technical ...
# 4321  specialist 3 years of professional experience ...
# 4323  of 3 years professional working experience in ...
# 4326  3 to 5 years of experience in a similar range ...
# 4327  or similar required knowledge professional exp...
# 4351  or measurement technique first work experience...
# 4368  equivalent experiences min 3 years experience ...
# 4505  at least 3 years working experience in square ...
# 4509  or technicians with appropriate work experienc...
# 4617  least 3 years of work experience desirably in ...
# 4618  industrial engineering mind5 years of experien...
# 4670  at least 3 years of experience in the automoti...
# 4696  qualification at least 3 years experience in o...
# 4837  bo admin and reporting security experience wor...
# 4879  desirably at least 2 years experience thorough...
# 4941  additional economic qualification or equivalen...
# 4942  additional economic qualification or equivalen...
# 5016  5 years of product development experience with...
# 5138  5 years several years of experience in the are...
# 5154  desired experiences 3 years of experience in s...
# 5243  experience after vzyklus desirable development...
# 5352  at least 5 years of experience in the developm...
# 5912  science electrical engineering or equivalent e...
# 5913  science electrical engineering or equivalent e...
# 6099  similar at least 8 years experience in the are...
# 6161  mechanical engineering 3 years of experience i...
# 6178  at least 5 years of experience in the relevant...
# 6218  siemens s7 plc programming and experience in i...
# 6369  technology 40 several years of experience in t...
# 6431  minimum of 3 years of experience in tire testi...
#
# [135 rows x 11 columns]

# %%
# try filter out the ones contain words of numbers from 1-10 "one" "two"

# %%
# filter out ones with words like "several" "a few" "a lot of"

# %%
data[data['extracted_experience'].notnull()]
# Out:
#         id                                       job_title_en  \
# 2     5371     3d printing specialist for packaging materials
# 4      360                                   account manager
# 5     5981                                   account manager
# 6     4907                                   account manager
# 7       80                                   account manager
# 8     1345                                   account manager
# 10    3161                                   account manager
# 12    6058                account manager asian accounts emea
# 13    2361  account manager autohaus in passenger tire rep...
# 14    3623                           account manager car ersd
# 15    4608                          account manager car fleet
# 16    3449                  account manager elevator industry
# 17    5973           account manager firmc railway solutions
# 18    2175  account manager in the area wholesale workshop...
# 19    2224                         account manager industrial
# 20    5176                      account manager mining europe
# 21    2879  account manager motorcycles for customers euro...
# 22    6130           account manager oe emea global executive
# 23    6164                         account manager powertrain
# 24    3625                  account manager railway solutions
# 25    4164  account manager renault  nissan  dacia emea  e...
# 26    3749  account manager roof oe commercial specialty t...
# 27    2179         account manager tier 1 customers executive
# 28    6165                      account manager tier 1 europe
# 29     593  account manager wholesale motorcycle tire cent...
# 30    1046                     account manager wholesale roof
# 31    3756  account to report global process architect  ex...
# 32     257                                        accountant
# 33    3285                                        accounting
# 35     627                                        accounting
# ...    ...                                                ...
# 6433  1519                          vehicle system architect
# 6434  4547  vehicle system architect twowheeler and powers...
# 6435  2876                      vehicle system test engineer
# 6438   676                              vehicle test engineer
# 6439  1906  vehicle test manager for driver assistant systems
# 6440  5544                           venture capital manager
# 6441   578                                   versandemployee
# 6443  3531     vetriebsclerk back office sales  bef to 311217
# 6444  3130        vice president bu tr engineering  executive
# 6445  5581                     virtual verification engineer
# 6446  6060  virtual verification engineer for automated dr...
# 6448  2396  visualization developer surround view driver a...
# 6449  5139  visualization software architect surround view...
# 6450  5386  visualization software developer  surround vie...
# 6451  1664                            vmware system engineer
# 6453  1382  wan architect in the automotive area it infras...
# 6454  5477            wan manager corporate it infrastructure
# 6456  3184                  warehousing distribution manager
# 6457  1025                  warehousing distribution manager
# 6458  6009              warehousing distribution manager emea
# 6460  3914                                werkschutzemployee
# 6462  2982  windows server and cloud architect focus citri...
# 6463  1652  windows server and cloud architect in the area...
# 6464  3073  windows server and cloud architect in the area...
# 6465  6066                   wireless communication engineer
# 6466  6095                            wireless test engineer
# 6467  1620                            wireless test engineer
# 6468  4032  work preparation and general sap master data m...
# 6470  1239     workshop leader firmc engineering services ces
# 6471  3011                                     yield manager
#
#                                      job_requirement_en  \
# 2     academic degree in mechanical engineering  pac...
# 4     a degree in the engineering field several year...
# 5     academic degree in economics engineering indus...
# 6     degree ideally in the industrial engineering a...
# 7     degree in engineering mechanical engineering a...
# 8     degree in industrial engineering engineering s...
# 10    successfully completed a technical or economic...
# 12    academic degree in engineering mechanical engi...
# 13    concluded kaufmtechn training with acquired in...
# 14    completed business administration studies sale...
# 15    completed studies in business administration o...
# 16    degree of engineering  or industrial engineeri...
# 17    successfully completed technical or business s...
# 18    degree in the economics or engineering or simi...
# 19    degree business administration  or ing m  w wi...
# 20    completed technical or commercial studies with...
# 21    academic degree in the field of economics or e...
# 22    academic degree in engineering natural science...
# 23    academic degree in electronic or mechanical en...
# 24    successfully completed technical or business d...
# 25    academic degree in engineering mechanical engi...
# 26    completed business management  technical studi...
# 27    academic degree in engineering or economics se...
# 28    academic degree in engineering preferably indu...
# 29    completed commercial studies or completed comm...
# 30    degree in engineering or business or equivalen...
# 31    degree in accounting or related field profound...
# 32    completed commercial training with additional ...
# 33    completed commercial vocational training as as...
# 35    fully trained industrial business  woman or si...
# ...                                                 ...
# 6433  degree dipling mechatronic mechanical engineer...
# 6434  masters degree in engineering multiyear experi...
# 6435  degree in engineering automotive engineering o...
# 6438  degree in electrical engineering mechatronics ...
# 6439  degree in engineering or similar vehicle sever...
# 6440  academic degree in business administration eco...
# 6441  completed commercial training operational work...
# 6443  successfully completed commercial vocational t...
# 6444  university degree in electrical or mechanical ...
# 6445  closed degree in electronic automotive communi...
# 6446  degree in electrical engineering computer scie...
# 6448  master or ba in computer science physics mathe...
# 6449  phd master or ba in computer science computer ...
# 6450  master or ba in computer science physics mathe...
# 6451  completed studies in computer science virtuali...
# 6453  degree of information technology economy compu...
# 6454  studies in the field of information technology...
# 6456  degree in business studies  economics engineer...
# 6457  degree in business studies  economics engineer...
# 6458  degree in business studies  economics engineer...
# 6460  completed vocational training trained professi...
# 6462  academic degree in information technology or c...
# 6463  degree of information technology or similar qu...
# 6464  degree of information technology or similar qu...
# 6465  university degree in electrical engineering co...
# 6466  academic degree in radio frequency telecommuni...
# 6467  bachelor or master degree in electrical engine...
# 6468  completed training as a technician or master i...
# 6470  completed training in the area of motor vehicl...
# 6471  degree in engineering or in similar technical ...
#
#                                      job_description_en  \
# 2     Establishing a global 3d printing strategy for...
# 4     as accoutn manager (m / w) of the business uni...
# 5     determination & development of customer relati...
# 6     development of strategic partnerships with wel...
# 7     We are looking for our automotive sector a key...
# 8     support and build strategic partnerships and r...
# 10    responsible and perception of the sales suppor...
# 12    Ensure the business with the oem in order to a...
# 13    care and intensification of the business relat...
# 14    development and implementation of strategy com...
# 15    care of the leasing companies and fpm or fleet...
# 16    for firmc drive systems gmbh in danne mountain...
# 17    promotion of profitable growth by building and...
# 18    develop and implement sales strategies, polici...
# 19    development and expansion of business volume, ...
# 20    development of strategic partnerships with key...
# 21    the key account manager (m / f) motorcycles fo...
# 22    Ensure the emea business (tires and affiliated...
# 23    the account manager Participates in the custom...
# 24    promotion of profitable growth by building and...
# 25    support the global key account management in t...
# 26    the spot is to be filled to 100% in the home o...
# 27    Ensure Sustainable business growth with tier 1...
# 28    business development and operational sales:\n\...
# 29    independent intensive care of existing and ong...
# 30    design and develop of customer and sales strat...
# 31    in your role as account to report global proce...
# 32    support of the management of the external acco...
# 33    control and accounting of purchase invoices fr...
# 35    audit and book purchase invoices for supplies,...
# ...                                                 ...
# 6433  development of e / e architectures within firm...
# 6434  we are looking for a vehicle system architect ...
# 6435  support for development of the system function...
# 6438  the firmc Engineering Services (CES) is embedd...
# 6439  They are the contact for all internal and exte...
# 6440  build up, maintenance and development of a net...
# 6441  as a shipping employee (m / f) for the product...
# 6443  expires on 12/31/2017 - even in some time.\n\n...
# 6444  leading of a global, matrixed organization in ...
# 6445  implementation of hil-systems in design or cus...
# 6446  commissioning of hil-systems\n\n further devel...
# 6448  camera based 3D reconstruction (3D picture qua...
# 6449  development of a modular multiplatform softwar...
# 6450  join our team as a visualization software deve...
# 6451  for one of our sites or Regensburg eschborn we...
# 6453  as wan architect they develop from the Frankfu...
# 6454  the spot can be filled both in Eschborn (near ...
# 6456  optimization of logistics processes in warehou...
# 6457  optimization of logistics processes in warehou...
# 6458  optimization of logistics processes in warehou...
# 6460  regulation, control and monitoring of the flow...
# 6462  consulting support for customers Regarding ser...
# 6463  assisting in the design and the architecture o...
# 6464  assisting in the design and the architecture o...
# 6465  characterization of integrated receiver and tr...
# 6466  cooperation in radio frequency test team (test...
# 6467  we are testing automotive network devices Incl...
# 6468  system of master data in the ERP system as wel...
# 6470  the firmc engineering services gmbh (ces) is e...
# 6471  Ensure continuous improvement of the yield in ...
#
#                                            job_category  \
# 2                                      logistics--other
# 4     marketing and sales--service customer support,...
# 5     key account management--key account management...
# 6     marketing and sales--service customer support,...
# 7        key account management--key account management
# 8        key account management--key account management
# 10       key account management--key account management
# 12       key account management--key account management
# 13          marketing and sales--sales and distribution
# 14    key account management--key account management...
# 15       key account management--key account management
# 16       key account management--key account management
# 17        marketing and sales--service customer support
# 18    key account management--key account management...
# 19    key account management--key account management...
# 20          marketing and sales--sales and distribution
# 21       key account management--key account management
# 22       key account management--key account management
# 23    key account management--key account management...
# 24                       marketing and sales--marketing
# 25                engineering--other,general management
# 26    marketing and sales--sales and distribution,ma...
# 27    key account management--key account management...
# 28       key account management--key account management
# 29        marketing and sales--service customer support
# 30        marketing and sales--service customer support
# 31    finance and controlling--controlling,finance a...
# 32                  finance and controlling--accounting
# 33                  finance and controlling--accounting
# 35                  finance and controlling--accounting
# ...                                                 ...
# 6433  research and development--other,engineering--o...
# 6434  engineering--engineering,project management--p...
# 6435                           engineering--engineering
# 6438  research and development--other,research and d...
# 6439  engineering--engineering,engineering--software...
# 6440  mergers and acquisitions--mergers and acquisit...
# 6441                                   logistics--other
# 6443      marketing and sales--service customer support
# 6444        engineering--engineering,general management
# 6445  engineering--other,engineering--engineering,en...
# 6446     engineering--engineering,engineering--software
# 6448                           engineering--engineering
# 6449  engineering--engineering,engineering--software...
# 6450  engineering--engineering,engineering--software...
# 6451  information technology--data processing/hardwa...
# 6453  information technology--data processing/hardwa...
# 6454  information technology--administration/managem...
# 6456                                   logistics--other
# 6457                                   logistics--other
# 6458                            logistics--distribution
# 6460  facility management--facility management,healt...
# 6462  information technology--consulting,information...
# 6463  information technology--administration/managem...
# 6464  information technology--administration/managem...
# 6465                                 engineering--other
# 6466        engineering--engineering,engineering--other
# 6467  research and development--quality assurance an...
# 6468  industrial engineering--industrial engineering...
# 6470                           engineering--engineering
# 6471  quality--manufacturing and production,quality-...
#
#                       job_area          job_area_oneword  \
# 2                    logistics                 logistics
# 4          marketing and sales       marketing_and_sales
# 5       key account management    key_account_management
# 6          marketing and sales       marketing_and_sales
# 7       key account management    key_account_management
# 8       key account management    key_account_management
# 10      key account management    key_account_management
# 12      key account management    key_account_management
# 13         marketing and sales       marketing_and_sales
# 14      key account management    key_account_management
# 15      key account management    key_account_management
# 16      key account management    key_account_management
# 17         marketing and sales       marketing_and_sales
# 18      key account management    key_account_management
# 19      key account management    key_account_management
# 20         marketing and sales       marketing_and_sales
# 21      key account management    key_account_management
# 22      key account management    key_account_management
# 23      key account management    key_account_management
# 24         marketing and sales       marketing_and_sales
# 25                 engineering               engineering
# 26         marketing and sales       marketing_and_sales
# 27      key account management    key_account_management
# 28      key account management    key_account_management
# 29         marketing and sales       marketing_and_sales
# 30         marketing and sales       marketing_and_sales
# 31     finance and controlling   finance_and_controlling
# 32     finance and controlling   finance_and_controlling
# 33     finance and controlling   finance_and_controlling
# 35     finance and controlling   finance_and_controlling
# ...                        ...                       ...
# 6433  research and development  research_and_development
# 6434               engineering               engineering
# 6435               engineering               engineering
# 6438  research and development  research_and_development
# 6439               engineering               engineering
# 6440  mergers and acquisitions  mergers_and_acquisitions
# 6441                 logistics                 logistics
# 6443       marketing and sales       marketing_and_sales
# 6444               engineering               engineering
# 6445               engineering               engineering
# 6446               engineering               engineering
# 6448               engineering               engineering
# 6449               engineering               engineering
# 6450               engineering               engineering
# 6451    information technology    information_technology
# 6453    information technology    information_technology
# 6454    information technology    information_technology
# 6456                 logistics                 logistics
# 6457                 logistics                 logistics
# 6458                 logistics                 logistics
# 6460       facility management       facility_management
# 6462    information technology    information_technology
# 6463    information technology    information_technology
# 6464    information technology    information_technology
# 6465               engineering               engineering
# 6466               engineering               engineering
# 6467  research and development  research_and_development
# 6468    industrial engineering    industrial_engineering
# 6470               engineering               engineering
# 6471                   quality                   quality
#
#               job_area_broader    job_rank  job_degree  \
# 2                    logistics  specialist        None
# 4          marketing_and_sales     manager        None
# 5          marketing_and_sales     manager        None
# 6          marketing_and_sales     manager        None
# 7          marketing_and_sales     manager        None
# 8          marketing_and_sales     manager        None
# 10         marketing_and_sales     manager        None
# 12         marketing_and_sales     manager        None
# 13         marketing_and_sales     manager        None
# 14         marketing_and_sales     manager        None
# 15         marketing_and_sales     manager        None
# 16         marketing_and_sales     manager        None
# 17         marketing_and_sales     manager        None
# 18         marketing_and_sales     manager        None
# 19         marketing_and_sales     manager        None
# 20         marketing_and_sales     manager        None
# 21         marketing_and_sales     manager        None
# 22         marketing_and_sales     manager        None
# 23         marketing_and_sales     manager        None
# 24         marketing_and_sales     manager        None
# 25                 engineering     manager        None
# 26         marketing_and_sales     manager        None
# 27         marketing_and_sales     manager        None
# 28         marketing_and_sales     manager        None
# 29         marketing_and_sales     manager        None
# 30         marketing_and_sales     manager        None
# 31                     finance        None        None
# 32                     finance        None        None
# 33                     finance        None        None
# 35                     finance        None        None
# ...                        ...         ...         ...
# 6433               engineering        None        None
# 6434               engineering        None      master
# 6435               engineering        None        None
# 6438               engineering        None        None
# 6439               engineering   assistant        None
# 6440  mergers_and_acquisitions     manager        None
# 6441                 logistics        None        None
# 6443       marketing_and_sales        None        None
# 6444               engineering        None      master
# 6445               engineering        None        None
# 6446               engineering        None        None
# 6448               engineering        None      master
# 6449               engineering        None      master
# 6450               engineering        None      master
# 6451    information_technology        None        None
# 6453    information_technology        None        None
# 6454    information_technology     manager        None
# 6456                 logistics     manager        None
# 6457                 logistics     manager        None
# 6458                 logistics     manager        None
# 6460       facility_management        None        None
# 6462    information_technology        None        None
# 6463    information_technology        None        None
# 6464    information_technology        None        None
# 6465               engineering        None  university
# 6466               engineering        None        None
# 6467               engineering        None      master
# 6468               engineering        None      master
# 6470               engineering        lead      master
# 6471                   quality     manager        None
#
#                                    extracted_experience
# 2     several years of professional work experience ...
# 4     beneficial good business management basic expe...
# 5     engineering industrial engineering or similar ...
# 6     pro several years of professional experience i...
# 7     and economics several years of experience in t...
# 8     sciences or economics with technical experienc...
# 10    economics studies several years of experience ...
# 12    or oe development first leadership experience ...
# 13    or similar qualifications perennial sales expe...
# 14    more years of relevant work experience in sale...
# 15    administration or similar perennial sales expe...
# 16    founded several years of work experience in re...
# 17    in and have several years experience in the fi...
# 18    qualifications several years of professional e...
# 19    training several years of professional experie...
# 20    technical pro several years of experience in t...
# 21    economics or engineering profound sales experi...
# 22    knowledge advanced negotiations skills leaders...
# 23    engineering many years of professional experie...
# 24    well as several years of experience in the bog...
# 25    several years of profound professional experie...
# 26    knowledge several years of operational experie...
# 27    or economics several years of experience in au...
# 28    and management several years of experience in ...
# 29    commercial education with relevant work experi...
# 30    or equivalent several years of experience in t...
# 31    with increasing responsibilities and global ex...
# 32    accountant several years of professional exper...
# 33    similar several years of professional experien...
# 35    woman or similar qualifications first experien...
# ...                                                 ...
# 6433  system and network knowledge desirable experie...
# 6434  masters degree in engineering multiyear experi...
# 6435  of study many years of experience in running a...
# 6438  technology or comparable courses first experie...
# 6439  similar vehicle several years of experience in...
# 6440  capital investment professional with extensive...
# 6441  completed commercial training operational work...
# 6443  training several years of professional experie...
# 6444  qualification long term of professional experi...
# 6445  or a comparable study first experience in the ...
# 6446  technology or a similar qualification experien...
# 6448  c matlab and open cv experience is a big plus ...
# 6449  etc several years of professional experience i...
# 6450  c matlab and open cv experience is a big plus ...
# 6451  virtualization environments several years of e...
# 6453  or similar qualifications operationally releva...
# 6454  qualifications several years of professional e...
# 6456  or similar first relevant work experience need...
# 6457  management or similar relevant work experience...
# 6458  or similar first relevant work experience need...
# 6460  desirable higher several years of experience i...
# 6462  comparable several years of working experience...
# 6463  or similar qualifications sound work experienc...
# 6464  or similar qualifications sound work experienc...
# 6465  communications or equivalent first work experi...
# 6466  methods and measuring procedures rf experience...
# 6467  other comparable studies several years experie...
# 6468  engineering mechatronics or industrial mechani...
# 6470  graduation master stamps or similar experience...
# 6471  technical fields several years of experience i...
#
# [5229 rows x 11 columns]
